# %% [markdown]
# # **AI And Biotechnology/Bioinformatics**
#
# ## **AI and Drug Discovery Course: QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.6 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.9 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.1 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Step 1: Search for Traget Protein
#
# ## **Target Identification (FGFR2)**
# Search ChEMBL for the FGFR2 target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("FGFR2")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Mus musculus
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                            pref_name  score  \
# 0                             Protein cereblon/FGFR2   16.0
# 1                Fibroblast growth factor receptor 2   15.0
# 2                Fibroblast growth factor receptor 2   15.0
# 3  von Hippel-Lindau disease tumor suppressor/Fib...   13.0
# 4  VEGF-receptor 2 and Fibroblast growth factor r...   11.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL5291678
# 1               False       CHEMBL4142
# 2               False       CHEMBL3648
# 3               False    CHEMBL6066126
# 4               False    CHEMBL2111434
#
#                                    target_components  \
# 0  [{'accession': 'P21802', 'component_descriptio...
# 1  [{'accession': 'P21802', 'component_descriptio...
# 2  [{'accession': 'P21803', 'component_descriptio...
# 3  [{'accession': 'P21802', 'component_descriptio...
# 4  [{'accession': 'P35968', 'component_descriptio...
#
#                    target_type  tax_id
# 0  PROTEIN-PROTEIN INTERACTION    9606
# 1               SINGLE PROTEIN    9606
# 2               SINGLE PROTEIN   10090
# 3  PROTEIN-PROTEIN INTERACTION    9606
# 4            SELECTIVITY GROUP    9606

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL4142'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **Fibroblast growth factor receptor 2(CHEMBL4142)** with reported IC 50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       506179                  []
# 1        None             None       633825                  []
# 2        None             None       636086                  []
# 3        None             None       641018                  []
# 4        None             None       642324                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL678693  Inhibition of Fibroblast growth factor receptor 2
# 1    CHEMBL678691  In vitro inhibition against autophosphorylatio...
# 2    CHEMBL678691  In vitro inhibition against autophosphorylatio...
# 3    CHEMBL678691  In vitro inhibition against autophosphorylatio...
# 4    CHEMBL678691  In vitro inhibition against autophosphorylatio...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                     target_pref_name target_tax_id  \
# 0    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 1    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 2    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 3    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 4    Homo sapiens  Fibroblast growth factor receptor 2          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  IC50    uM  UO_0000065        None   0.94
# 1       None  None  IC50    nM  UO_0000065        None   54.0
# 2       None  None  IC50    nM  UO_0000065        None  190.0
# 3       None  None  IC50    nM  UO_0000065        None  260.0
# 4       None  None  IC50    nM  UO_0000065        None  130.0
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in foler "data"**

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 6401
# -rw------- 1 root root 6553959 Jan 26 19:28 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,506179,[],CHEMBL678693,Inhibition of Fibroblast growth factor receptor 2,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)(C)c1nc2c3ccc(F)cc3c3c(=O)[nH]ccc3c2[nH]1,,,CHEMBL1135866,Bioorg Med Chem Lett,2002.0,"{'bei': '19.48', 'le': '0.36', 'lle': '2.04', 'sei': '9.79'}",CHEMBL21156,,CHEMBL21156,6.03,0,http://www.openphacts.org/units/Nanomolar,25954,=,1,1,=,,IC50,nM,,940.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,uM,UO_0000065,,0.94
# ,,633825,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)cc3F)c2cc1OC,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '16.28', 'le': '0.30', 'lle': '0.05', 'sei': '13.81'}",CHEMBL169837,,CHEMBL169837,7.27,0,http://www.openphacts.org/units/Nanomolar,336049,=,1,1,=,,IC50,nM,,54.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,54.0
# ,,636086,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2nccc(Oc3ccc(C(=O)c4ccc(C(C)(C)C)cc4)cc3)c2cc1OC,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '15.22', 'le': '0.28', 'lle': '0.15', 'sei': '11.66'}",CHEMBL171413,,CHEMBL171413,6.72,0,http://www.openphacts.org/units/Nanomolar,336044,=,1,1,=,,IC50,nM,,190.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,190.0
# ,,641018,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2c(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(F)c3)ccnc2cc1OCCNCCO,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '12.67', 'le': '0.24', 'lle': '0.41', 'sei': '7.76'}",CHEMBL354224,,CHEMBL354224,6.58,0,http://www.openphacts.org/units/Nanomolar,336058,=,1,1,=,,IC50,nM,,260.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,260.0
# ,,642324,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(C)c3C)c2cc1OC,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '15.08', 'le': '0.28', 'lle': '-0.81', 'sei': '13.09'}",CHEMBL167425,,CHEMBL167425,6.89,0,http://www.openphacts.org/units/Nanomolar,336051,=,1,1,=,,IC50,nM,,130.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,130.0
# ,,642325,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2c(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)cc3)ccnc2cc1OCCN1CCOCC1,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '12.70', 'le': '0.23', 'lle': '-0.09', 'sei': '10.29'}",CHEMBL354902,,CHEMBL354902,6.70,0,http://www.openphacts.org/units/Nanomolar,336062,=,1,1,=,,IC50,nM,,200.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,200.0
# ,,645873,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(C)c3)c2cc1OC,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '15.82', 'le': '0.29', 'lle': '-0.39', 'sei': '13.31'}",CHEMBL169854,,CHEMBL169854,7.00,0,http://www.openphacts.org/units/Nanomolar,336053,=,1,1,=,,IC50,nM,,100.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,100.0
# ,,645874,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2c(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)cc3)ccnc2cc1OCCN1CCC(CO)CC1,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '13.74', 'le': '0.25', 'lle': '0.48', 'sei': '10.04'}",CHEMBL171509,,CHEMBL171509,7.64,0,http://www.openphacts.org/units/Nanomolar,336060,=,1,1,=,,IC50,nM,,23.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,23.0
# ,,647048,[],CHEMBL678691,In vitro inhibition against autophosphorylation of Fibroblast growth factor receptor 2 in the human scirrhous gastric carcinoma cell line,B,,,BAO_0000190,BAO_0000019,assay format,COc1cc2nccc(Oc3ccc(NC4CCC(C(C)(C)C)CC4)cc3)c2cc1OC,,,CHEMBL1146677,Bioorg Med Chem Lett,2004.0,"{'bei': '12.58', 'le': '0.23', 'lle': '-1.59', 'sei': '10.39'}",CHEMBL352534,,CHEMBL352534,5.47,0,http://www.openphacts.org/units/Nanomolar,336047,=,1,1,=,,IC50,nM,,3400.0,CHEMBL4142,Homo sapiens,Fibroblast growth factor receptor 2,9606,,,IC50,nM,UO_0000065,,3400.0

# %% [markdown]
# # **Step 3: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected FGFR2 target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       506179                  []
# 1        None             None       633825                  []
# 2        None             None       636086                  []
# 3        None             None       641018                  []
# 4        None             None       642324                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL678693  Inhibition of Fibroblast growth factor receptor 2
# 1    CHEMBL678691  In vitro inhibition against autophosphorylatio...
# 2    CHEMBL678691  In vitro inhibition against autophosphorylatio...
# 3    CHEMBL678691  In vitro inhibition against autophosphorylatio...
# 4    CHEMBL678691  In vitro inhibition against autophosphorylatio...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                     target_pref_name target_tax_id  \
# 0    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 1    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 2    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 3    Homo sapiens  Fibroblast growth factor receptor 2          9606
# 4    Homo sapiens  Fibroblast growth factor receptor 2          9606
#
#   text_value  toid  type units    uo_units upper_value  value
# 0       None  None  IC50    uM  UO_0000065        None   0.94
# 1       None  None  IC50    nM  UO_0000065        None   54.0
# 2       None  None  IC50    nM  UO_0000065        None  190.0
# 3       None  None  IC50    nM  UO_0000065        None  260.0
# 4       None  None  IC50    nM  UO_0000065        None  130.0
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL21156     CC(C)(C)c1nc2c3ccc(F)cc3c3c(=O)[nH]ccc3c2[nH]1
# 1       CHEMBL169837  COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)cc3F)c2...
# 2       CHEMBL171413  COc1cc2nccc(Oc3ccc(C(=O)c4ccc(C(C)(C)C)cc4)cc3...
# 3       CHEMBL354224  COc1cc2c(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(F)c3)ccn...
# 4       CHEMBL167425  COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(C)c3C...
#
#   standard_value bioactivity_class
# 0          940.0            active
# 1           54.0            active
# 2          190.0            active
# 3          260.0            active
# 4          130.0            active

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL21156     CC(C)(C)c1nc2c3ccc(F)cc3c3c(=O)[nH]ccc3c2[nH]1
# 1       CHEMBL169837  COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)cc3F)c2...
# 2       CHEMBL171413  COc1cc2nccc(Oc3ccc(C(=O)c4ccc(C(C)(C)C)cc4)cc3...
# 3       CHEMBL354224  COc1cc2c(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(F)c3)ccn...
# 4       CHEMBL167425  COc1cc2nccc(Oc3ccc(Nc4ccc(C(C)(C)C)cc4)c(C)c3C...
#
#   standard_value bioactivity_class
# 0          940.0            active
# 1           54.0            active
# 2          190.0            active
# 3          260.0            active
# 4          130.0            active

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
